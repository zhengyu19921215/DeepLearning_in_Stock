from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
interNum=20
lstm_node=50
lstm_layers=2
input_dim=2
dense_size=100

# %%
open_input=Input(shape=(timeSteps,input_dim),name='open_input')
close_input=Input(shape=(timeSteps,input_dim),name='close_input')
high_input=Input(shape=(timeSteps,input_dim),name='high_input')
low_input=Input(shape=(timeSteps,input_dim),name='low_input')
volume_input=Input(shape=(timeSteps,input_dim),name='volume_input')
p_change_input=Input(shape=(timeSteps,input_dim),name='p_change_input')

# %%
open_inter=Dense(interNum,activation='tanh')(open_input)
close_inter=Dense(interNum,activation='tanh')(close_input)
high_inter=Dense(interNum,activation='tanh')(high_input)
low_inter=Dense(interNum,activation='tanh')(low_input)
volume_inter=Dense(interNum,activation='tanh')(volume_input)
p_change_inter=Dense(interNum,activation='tanh')(p_change_input)

# %%
combine=Concatenate()([open_inter,close_inter,high_inter,low_inter,volume_inter,p_change_inter])
# combine=Concatenate()([open_input,close_input,high_input,low_input,volume_input,p_change_input])

# %%
lstm_out=AttentionLSTM(lstm_node)(combine)

# %%
x=Dense(dense_size,activation='tanh')(lstm_out)
out=Dense(1,name='open_output')(x)

# %%
model=Model(inputs=[open_input,close_input,high_input,low_input,volume_input,p_change_input],outputs=out)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# open_input (InputLayer)          (None, 30, 2)         0
# ____________________________________________________________________________________________________
# close_input (InputLayer)         (None, 30, 2)         0
# ____________________________________________________________________________________________________
# high_input (InputLayer)          (None, 30, 2)         0
# ____________________________________________________________________________________________________
# low_input (InputLayer)           (None, 30, 2)         0
# ____________________________________________________________________________________________________
# volume_input (InputLayer)        (None, 30, 2)         0
# ____________________________________________________________________________________________________
# p_change_input (InputLayer)      (None, 30, 2)         0
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 30, 20)        60          open_input[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 30, 20)        60          close_input[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 30, 20)        60          high_input[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 30, 20)        60          low_input[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 30, 20)        60          volume_input[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 30, 20)        60          p_change_input[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 30, 120)       0           dense_1[0][0]
#                                                                    dense_2[0][0]
#                                                                    dense_3[0][0]
#                                                                    dense_4[0][0]
#                                                                    dense_5[0][0]
#                                                                    dense_6[0][0]
# ____________________________________________________________________________________________________
# attention_lstm_1 (AttentionLSTM) (None, 50)            66800       concatenate_1[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 100)           5100        attention_lstm_1[0][0]
# ____________________________________________________________________________________________________
# open_output (Dense)              (None, 1)             101         dense_7[0][0]
# ====================================================================================================
# Total params: 72,361
# Trainable params: 72,361
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
model_checkpoint = ModelCheckpoint("./weights/weights.h5", verbose=1,
                                       monitor='val_loss', save_best_only=True, save_weights_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',verbose=1,factor=0.5,min_lr=1e-5)
callback_list = [model_checkpoint, reduce_lr]

# %%
lr=1e-3
optm=keras.optimizers.Adam(lr=lr)
# model.compile(loss='mse',optimizer=optm,metrics=['mae'])
model.compile(loss='mse',optimizer=optm)

# %% [markdown]
# ---

# %%
import pywt
import numpy as np

# %%
Wfn = pywt.Wavelet('dmey')

# %%
class StoreDataSet:
    def __init__(self,sK,prop,S_length,prepro):
        self.K=sK
        self.S_length=S_length
        self.prop=prop
        self.sp=sK[prop].values
        self.prepro=prepro
    def __len__(self):
        return len(self.K)-self.S_length
    def __getitem__(self,idx):
        if self.prepro is True:
            st=self.sp[idx:idx+self.S_length]
            cof=pywt.swt(st, Wfn,level=1)
            ca=np.expand_dims(cof[0][0], axis=-1)
            cd=np.expand_dims(cof[0][1],axis=-1)
            r=np.concatenate((ca,cd), axis=-1)
        else:
            r=self.sp[idx+self.S_length]
        return r

# %%
props=['open','close','high','low','volume','p_change']
def get_dateSet(aK,prepro):
    trainSet={}
    for prop in props:
        t=StoreDataSet(aK,prop,timeSteps,prepro)
        s=None
        for i in range(len(t)):
            if i==0:
                s=np.expand_dims(t[i], axis=0)
            else:
                s=np.concatenate((s,np.expand_dims(t[i],axis=0)))
        if prepro is True:
            prop=prop+'_input'
        else:
            prop=prop+'_output'
        trainSet[prop]=s
    return trainSet

# %%
trainInSet=get_dateSet(train_K,True)
trainOutSet=get_dateSet(train_K,False)
valInSet=get_dateSet(val_K,True)
valOutSet=get_dateSet(val_K,False)

# %%
trainInSet.keys(),trainOutSet.keys()
# Out:
# (dict_keys(['open_input', 'close_input', 'high_input', 'low_input', 'volume_input', 'p_change_input']),
#  dict_keys(['open_output', 'close_output', 'high_output', 'low_output', 'volume_output', 'p_change_output']))

# %%
trainInSet['open_input'].shape,trainOutSet['open_output'].shape
# Out:
# ((412, 30, 2), (412,))

# %%
valInSet['open_input'].shape,valOutSet['open_output'].shape
# Out:
# ((100, 30, 2), (100,))

# %% [markdown]
# ---

# %%
hist=model.fit(trainInSet,trainOutSet,epochs=70,batch_size=10,validation_data=(
    valInSet,valOutSet),callbacks=callback_list)
# Out:
# Train on 412 samples, validate on 100 samples
# Epoch 1/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0189Epoch 00000: val_loss improved from inf to 0.00220, saving model to ./weights/weights.h5
# 412/412 [==============================] - 10s - loss: 0.0188 - val_loss: 0.0022
# Epoch 2/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0037Epoch 00001: val_loss improved from 0.00220 to 0.00046, saving model to ./weights/weights.h5
# 412/412 [==============================] - 6s - loss: 0.0037 - val_loss: 4.6011e-04
# Epoch 3/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0029Epoch 00002: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0029 - val_loss: 9.0358e-04
# Epoch 4/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0022Epoch 00003: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0022 - val_loss: 0.0015
# Epoch 5/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0021Epoch 00004: val_loss improved from 0.00046 to 0.00007, saving model to ./weights/weights.h5
# 412/412 [==============================] - 5s - loss: 0.0021 - val_loss: 7.3811e-05
# Epoch 6/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0019Epoch 00005: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0018 - val_loss: 0.0011
# Epoch 7/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0018Epoch 00006: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0018 - val_loss: 0.0046
# Epoch 8/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0022Epoch 00007: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0022 - val_loss: 0.0012
# Epoch 9/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0016Epoch 00008: val_loss improved from 0.00007 to 0.00006, saving model to ./weights/weights.h5
# 412/412 [==============================] - 5s - loss: 0.0016 - val_loss: 5.7724e-05
# Epoch 10/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00009: val_loss did not improve
# 412/412 [==============================] - 7s - loss: 0.0014 - val_loss: 8.5229e-05
# Epoch 11/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0017Epoch 00010: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0017 - val_loss: 8.7514e-04
# Epoch 12/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0015Epoch 00011: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0015 - val_loss: 1.1280e-04
# Epoch 13/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0015Epoch 00012: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0015 - val_loss: 4.9881e-04
# Epoch 14/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0017Epoch 00013: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0017 - val_loss: 6.8624e-05
# Epoch 15/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0016Epoch 00014: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0016 - val_loss: 2.2413e-04
# Epoch 16/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0012Epoch 00015: val_loss did not improve
#
# Epoch 00015: reducing learning rate to 0.0005000000237487257.
# 412/412 [==============================] - 6s - loss: 0.0012 - val_loss: 1.4207e-04
# Epoch 17/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00016: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0014 - val_loss: 0.0012
# Epoch 18/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00017: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0014 - val_loss: 4.6504e-04
# Epoch 19/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00018: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0011 - val_loss: 2.1240e-04
# Epoch 20/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00019: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0011 - val_loss: 2.7914e-04
# Epoch 21/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0012Epoch 00020: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0012 - val_loss: 2.9051e-04
# Epoch 22/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00021: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0011 - val_loss: 1.4006e-04
# Epoch 23/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00022: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0011 - val_loss: 8.3571e-04
# Epoch 24/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00023: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 0.0011 - val_loss: 9.6198e-05
# Epoch 25/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0010Epoch 00024: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0010 - val_loss: 3.1872e-04
# Epoch 26/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0014Epoch 00025: val_loss did not improve
#
# Epoch 00025: reducing learning rate to 0.0002500000118743628.
# 412/412 [==============================] - 5s - loss: 0.0014 - val_loss: 6.2163e-04
# Epoch 27/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0010Epoch 00026: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0010 - val_loss: 3.3629e-04
# Epoch 28/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0011Epoch 00027: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0011 - val_loss: 2.1819e-04
# Epoch 29/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0010Epoch 00028: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0010 - val_loss: 8.8560e-05
# Epoch 30/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.6165e-04Epoch 00029: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.5704e-04 - val_loss: 4.3960e-04
# Epoch 31/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.9797e-04Epoch 00030: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.9929e-04 - val_loss: 7.7937e-04
# Epoch 32/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.8881e-04Epoch 00031: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.8560e-04 - val_loss: 8.5648e-04
# Epoch 33/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.6622e-04Epoch 00032: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.6163e-04 - val_loss: 1.4313e-04
# Epoch 34/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.9909e-04Epoch 00033: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.9498e-04 - val_loss: 3.7264e-04
# Epoch 35/70
# 410/412 [============================>.] - ETA: 0s - loss: 0.0010Epoch 00034: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 0.0010 - val_loss: 1.1391e-04
# Epoch 36/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.2748e-04Epoch 00035: val_loss did not improve
#
# Epoch 00035: reducing learning rate to 0.0001250000059371814.
# 412/412 [==============================] - 5s - loss: 9.2313e-04 - val_loss: 2.6149e-04
# Epoch 37/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.8105e-04Epoch 00036: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.7728e-04 - val_loss: 1.3680e-04
# Epoch 38/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.9700e-04Epoch 00037: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.9267e-04 - val_loss: 9.5588e-05
# Epoch 39/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.0168e-04Epoch 00038: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.3289e-04 - val_loss: 2.6259e-04
# Epoch 40/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.8247e-04Epoch 00039: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.0244e-04 - val_loss: 1.0884e-04
# Epoch 41/70
# 410/412 [============================>.] - ETA: 0s - loss: 9.1657e-04Epoch 00040: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 9.1230e-04 - val_loss: 8.9325e-05
# Epoch 42/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.6211e-04Epoch 00041: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.5862e-04 - val_loss: 1.5509e-04
# Epoch 43/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.1402e-04Epoch 00042: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.1016e-04 - val_loss: 1.1244e-04
# Epoch 44/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.2805e-04Epoch 00043: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.2409e-04 - val_loss: 1.1492e-04
# Epoch 45/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.2766e-04Epoch 00044: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 8.2424e-04 - val_loss: 8.7341e-05
# Epoch 46/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.2197e-04Epoch 00045: val_loss did not improve
#
# Epoch 00045: reducing learning rate to 6.25000029685907e-05.
# 412/412 [==============================] - 5s - loss: 8.1805e-04 - val_loss: 9.5510e-05
# Epoch 47/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.9297e-04Epoch 00046: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.8917e-04 - val_loss: 1.5838e-04
# Epoch 48/70
# 410/412 [============================>.] - ETA: 0s - loss: 8.1815e-04Epoch 00047: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 8.1429e-04 - val_loss: 1.3333e-04
# Epoch 49/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.6339e-04Epoch 00048: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.5979e-04 - val_loss: 1.2522e-04
# Epoch 50/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.5166e-04Epoch 00049: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.4937e-04 - val_loss: 9.2632e-05
# Epoch 51/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.8635e-04Epoch 00050: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.8322e-04 - val_loss: 1.2091e-04
# Epoch 52/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.6675e-04Epoch 00051: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.6341e-04 - val_loss: 8.4718e-05
# Epoch 53/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.8315e-04Epoch 00052: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.8116e-04 - val_loss: 1.5139e-04
# Epoch 54/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.6588e-04Epoch 00053: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.6247e-04 - val_loss: 1.2084e-04
# Epoch 55/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.5129e-04Epoch 00054: val_loss did not improve
# 412/412 [==============================] - 6s - loss: 7.4782e-04 - val_loss: 9.1448e-05
# Epoch 56/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.4582e-04Epoch 00055: val_loss did not improve
#
# Epoch 00055: reducing learning rate to 3.125000148429535e-05.
# 412/412 [==============================] - 5s - loss: 7.4246e-04 - val_loss: 9.2386e-05
# Epoch 57/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.3899e-04Epoch 00056: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.3932e-04 - val_loss: 1.0964e-04
# Epoch 58/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.4135e-04Epoch 00057: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.3797e-04 - val_loss: 1.1281e-04
# Epoch 59/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.2676e-04Epoch 00058: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.2421e-04 - val_loss: 9.3615e-05
# Epoch 60/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.3244e-04Epoch 00059: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.2976e-04 - val_loss: 9.3199e-05
# Epoch 61/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.1539e-04Epoch 00060: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.1959e-04 - val_loss: 9.2903e-05
# Epoch 62/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.5353e-04Epoch 00061: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.5030e-04 - val_loss: 9.3638e-05
# Epoch 63/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.3457e-04Epoch 00062: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.3110e-04 - val_loss: 1.1541e-04
# Epoch 64/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.2351e-04Epoch 00063: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.2095e-04 - val_loss: 9.0476e-05
# Epoch 65/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.1868e-04Epoch 00064: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.1534e-04 - val_loss: 1.0317e-04
# Epoch 66/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.1939e-04Epoch 00065: val_loss did not improve
#
# Epoch 00065: reducing learning rate to 1.5625000742147677e-05.
# 412/412 [==============================] - 5s - loss: 7.1834e-04 - val_loss: 9.2314e-05
# Epoch 67/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.1106e-04Epoch 00066: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.0785e-04 - val_loss: 9.0174e-05
# Epoch 68/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.0381e-04Epoch 00067: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.1367e-04 - val_loss: 8.8942e-05
# Epoch 69/70
# 410/412 [============================>.] - ETA: 0s - loss: 7.0759e-04Epoch 00068: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.0425e-04 - val_loss: 9.0410e-05
# Epoch 70/70
# 410/412 [============================>.] - ETA: 0s - loss: 6.9902e-04Epoch 00069: val_loss did not improve
# 412/412 [==============================] - 5s - loss: 7.0317e-04 - val_loss: 9.2346e-05

# %%
import pickle

f=open('./history.txt','wb')
pickle.dump(hist.history,f)
f.close()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
model.load_weights('./weights/weights.h5')

# %%
plt.title('Train')
plt.plot(trainOutSet['open_output'])
train_predict=model.predict(trainInSet)
plt.plot(train_predict)
plt.legend(['original','prediction'])

# %%
plt.title('Val')
plt.plot(valOutSet['open_output'])
val_predict=model.predict(valInSet)
plt.plot(val_predict)
plt.legend(['original','prediction'])

# %%
plt.title('Total')
to=np.concatenate((trainOutSet['open_output'],valOutSet['open_output']))
plt.plot(to)
po=np.concatenate((train_predict.reshape((-1)),val_predict.reshape((-1))))
plt.plot(po)
plt.legend(['original','prediction'])

# %% [markdown]
# ---

# %%
plt.title('Loss')
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['loss: %.6f'%min(hist.history['loss']),'val_loss: %.6f'%min(hist.history['val_loss'])])
